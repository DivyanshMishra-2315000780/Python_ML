# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyanshMishra-2315000780/Python_ML/blob/main/session1_python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Python Output

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Divyansh Mishra")
# Out:
# Divyansh Mishra

# %%
print(Divyansh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4210218634.py in <cell line: 0>()
# ----> 1 print(Divyansh)
#
# NameError: name 'Divyansh' is not defined

# %%
print(4)
# Out:
# 4

# %%
print(7.7)
# Out:
# 7.7

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4153662535.py in <cell line: 0>()
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(True)
# Out:
# True

# %%
print('Hello',3,35.5,True)
# Out:
# Hello 3 35.5 True

# %%
print('Hello',3,35.5,True,sep='/')
# Out:
# Hello/3/35.5/True

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2. Data Types

# %%
#Integer
print(8)
#1*10^308
print(1e308)
# Out:
# 8
# 1e+308

# %%
#Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print("Hello World")
# Out:
# Hello World

# %%
#Complex
print(5+6j)
print(3+4i)
# Out:
#   File "/tmp/ipython-input-2514175560.py", line 3
#     print(3+4i)
#             ^
# SyntaxError: invalid decimal literal

# %%
#Complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List -> c -> array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({'name':'Divyansh','gender':'Male','age':"21"})
# Out:
# {'name': 'Divyansh', 'gender': 'Male', 'age': '21'}

# %%
#type
type('23')
# Out:
# str

# %% [markdown]
# # 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
#c/c++
name = 'Divyansh'
print(name)

a=5
b=6

print(a+b)
# Out:
# Divyansh
# 11

# %%
a='Ashu'
b= 6
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3745253012.py in <cell line: 0>()
#       1 a='Ashu'
#       2 b= 6
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a='Ashu'
b= 6
print(a,b)
# Out:
# Ashu 6

# %%
#dynamic typing
a = 5
#static typing
int a = 5

# %%
#dynamic binding
a=5
print(a)
a = 'divyansh'
print(a)
# Out:
# 5
# divyansh

# %%
#python holds dynamic binding java c++ uses static binding

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
#this is a comment
#second line
a=4
b=6 #like this
# second comment
print(a+b)

# %% [markdown]
# # 4. Keywords and Identifiers

# %%
#keywords
#there are total 32 reserved words

# %%
#Identifiers
#You cannot start with a digit
name1 = 'divyansh'
print(name1)
#You can use special char -> _
_ = 'Divyansh'
print(_)
# Out:
# divyansh
# Divyansh

# %% [markdown]
# #5. User Input

# %%
# Static vs Dynamic
input('Enter your name')
# Out:
# Enter your nameDivyansh
# 'Divyansh'

# %%
#take input from users and store them in a variablee
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
#add the 2 variable
result = (fnum) + (snum)
#print the result
print(result)
print(type(result))
print(type(fnum))
# Out:
# enter first number23
# enter second number23
# 46
# <class 'int'>
# <class 'int'>

# %% [markdown]
# #6. Type Conversion

# %%
#Implicit vs Explicit
print(5+5.6)
print(type(5),type(5.6))

print(4+'4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-640361228.py in <cell line: 0>()
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4+'4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Explicit
#str -> int
#type(int('4'))
#int(4+5j)

#int to str
str(5)

#float
float(4)
# Out:
# 4.0

# %% [markdown]
# #7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310  #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10

# %%
a=None
print(a)
# Out:
# None

# %%
k = None
a = 5
b = 6
print('Program exe')

# %% [markdown]
# #8. Operators
